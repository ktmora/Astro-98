# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
"""
P = pressure
V = volume
R = ideal gas constant
n = number of mols
a, b = parameters (depende on what element(s) you're dealing with)
"""
# Out:
# "\nP = pressure\nV = volume\nR = ideal gas constant\na, b = parameters (depende on what element(s) you're dealing with)\n"

# %%
R = 0.083144
n = 1
a = 16.02
b = 0.1124
#pressure should vary between 1-10 bars
#volume should vary between 10 and 30 liters

x = P
y = V
z = T

x, y = np.meshgrid(np.linspace(1, 10, 100), np.linspace(10, 30, 100))
z = (((x+a*((n**2)/(y*y)))*(y-n*b))/(n*R)) #ideal gas law equation


plt.figure()
plt.imshow(z, cmap = 'inferno', origin = 'lower' )
plt.xlabel("Pressure")
plt.ylabel("Volume")
plt.colorbar()

plt.show()
