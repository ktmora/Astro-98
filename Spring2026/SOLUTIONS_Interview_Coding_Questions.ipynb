# %%
# SOLUTIONS : Spring 2026 Python Decal Interview Coding Questions


# 1 : Syntax
# Correct any possible syntax errors. 
# Parentheses around the print statements needed to be added, and function needs to be called at the end.

time = 12
def awake_or_not(): 
#     for time in range(0, 25):
    if time < 11: 
        print("Student is not awake.")
    elif time == 12:
        print("Student is awake, but rotting in bed.")
    else:
        print("Student is awake!")

awake_or_not()
# Out:
# Student is awake, but rotting in bed.

# %%
# 2 : Arrays
# Modify this function such that if each element in one row is the equivalent, it returns "True". 

import numpy as np

arr = np.array([[1, 1, 1],
                [4, 5, 6],
                [2, 2, 2]])

def find_equal(row):
    return np.all(. . .)

for row in arr:
    print(find_equal(row))

# %%
# 3 : While Loop
# Write a while loop that counts backwards from 20 in intervals of 2, and includes 0.

i = 20
while i > 0:
    print(i)
    i -= 2

# Now, write a function including your previous while loop that returns a numpy array of the values from the loop.

import numpy as np

arr = np.array(20)

def i_can_count(arr):
    i = 20 
    arr = np.array(20)
    while i > 0:
#         print(i)
        i -= 2
        arr = np.append(arr, i)
    print(arr)

i_can_count(arr)
