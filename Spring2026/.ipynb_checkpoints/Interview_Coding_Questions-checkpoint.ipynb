# %%
# Spring 2026 Python Decal Interview Coding Questions


# 1 : Syntax
# Correct any possible syntax errors. 
def winter_break(): 
    for student in winter_break:
        if time < 11: 
            print "Student is not awake."
        elif time == 12:
            print "Student is rotting in bed."
        else:
            print "Student is awake, but still rotting."

winter_break()



# 2 : Arrays
# Fix this function. 

# import numpy as np

# arr = np.array([[1, 1, 1], [1, 2, 3], [2, 2, 2]])
arr = [[1, 1, 1], [1, 2, 3], [2, 2, 2]]

print(arr[0])

def findEqual( a ) :
    i = arr[0]
    for j in range(len(i)) : 
        if a.all(arr[i]) == j :
            return True
        i += i
        j += j

print(findEqual(arr))

# 3 :
