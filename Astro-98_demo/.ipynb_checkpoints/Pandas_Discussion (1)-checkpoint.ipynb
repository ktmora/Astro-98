# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
#Solution for Part 1 here:
food_info = pd.DataFrame(data = { 'food' : [ 'Pad Thai' , 'Pizza' , 'Burger' , 'Boba' ] ,
'restaurant' : [ 'Imm Thai' , 'Cheeseboard' , 'Super Duper' , 'RareTea' ] , 
'price' : [ 16.00 , 24.50 , 7.00 , 6.50 ] } )

# %%
#Solution for Part 1 here:
food_info.loc[0:2:2, 'food']
# Out:
# 0    Pad Thai
# 2      Burger
# Name: food, dtype: object

# %%
#Solution for Part 2 here:
food_info.loc[0:1, 'food':'restaurant']
# Out:
#        food   restaurant
# 0  Pad Thai     Imm Thai
# 1     Pizza  Cheeseboard

# %%
#Solution for Part 3 here:
food_info.iloc[0:2, 0:3] #or you can put food_info.iloc[0:2, :], or just food_info.iloc[0:2]
# Out:
#        food   restaurant  price
# 0  Pad Thai     Imm Thai   16.0
# 1     Pizza  Cheeseboard   24.5

# %%
#Solution for Part 4 here:
food_info.iloc[0:3, 1:3]
# Out:
#     restaurant  price
# 0     Imm Thai   16.0
# 1  Cheeseboard   24.5
# 2  Super Duper    7.0

# %%
#Part 2.a
titanic = pd.read_csv('titanic_data.csv')
titanic.shape
display(titanic)
#Output format: rows, columns
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Part 2.b
titanic.loc[:, 'Survived']
survived = sum(titanic.loc[:, 'Survived'])
total_people = len(titanic.loc[:, 'PassengerId'])
survival_rate = ( survived / total_people ) * 100
print(survival_rate, '%')

#or could've done: titanic['Survived'].value_counts()[1] / sum(titanic['Survived'].value_counts())
# Out:
# 38.38383838383838 %

# %%
#Part 2.c
#names = titanic.loc[:, 'Name']
titanic.sort_values(by = ['Name'], ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 868          869         0       3            van Melkebeke, Mr. Philemon
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 286          287         1       3                de Mulder, Mr. Theodore
# ..           ...       ...     ...                                    ...
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 308          309         0       2                    Abelson, Mr. Samuel
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 845          846         0       3                    Abbing, Mr. Anthony
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...
